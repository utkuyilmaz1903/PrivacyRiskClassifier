# %% [markdown]
# # 01 - EDA ve Zayıf Etiketleme
#
# Bu defter, örnek izin verisini yükler, basit keşifler yapar ve kural tabanlı etiketleme fonksiyonunu gösterir.

# %%
import pandas as pd

from src import config
from src.features import build_feature_df

# Ham veriyi yükle
raw = pd.read_csv(config.RAW_DATA_PATH)
print("Ham veri örneği:")
print(raw.head())

# Özellik ve etiket üret
features = build_feature_df(raw)
print("\nEtiket dağılımı:")
print(features["label"].value_counts())

features.head()
